# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhsingroha/introtoaiml/blob/main/EXP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('/content/archive.zip')

# %%
df.head() # Show top 5 rows of the dataset.
# Out:
#    Rank              Name Date_of_birth           height  \
# 0     1     Anya Chalotra    1995-07-21   5′ 6″ (1.68 m)
# 1     2     Hayley Atwell    1982-04-05  5′ 6½″ (1.69 m)
# 2     3  Rebecca Ferguson    1983-10-19   5′ 5″ (1.65 m)
# 3     4     Vanessa Kirby    1988-04-18   5′ 7″ (1.70 m)
# 4     5        Tom Cruise    1962-07-03   5′ 7″ (1.70 m)
#
#                                     Role                           Awards  \
# 0                            ['Actress']                            1 win
# 1              ['Actress', 'Soundtrack']                   15 nominations
# 2  ['Actress', 'Soundtrack', 'Producer']                           9 wins
# 3  ['Actress', 'Soundtrack', 'Producer']    5 wins , 43 nominations total
# 4      ['Actor', 'Director', 'Producer']  59 wins , 108 nominations total
#
#                            Famous_for  \
# 0                         The Witcher
# 1  Captain America: The First Avenger
# 2                The Greatest Showman
# ...

# %%
df.tail() # Show last 5 rows of the dataset.
# Out:
#     Rank                Name Date_of_birth           height  \
# 95    96   Elizabeth Debicki    1990-08-24  6′ 2¾″ (1.90 m)
# 96    97      John Krasinski    1979-10-20   6′ 3″ (1.91 m)
# 97    98          Idris Elba    1972-09-06  6′ 2½″ (1.89 m)
# 98    99  Chloë Grace Moretz    1997-02-10   5′ 4″ (1.63 m)
# 99   100         Juno Temple    1989-07-21   5′ 2″ (1.57 m)
#
#                                      Role                           Awards  \
# 95                ['Actress', 'Producer']    6 wins , 38 nominations total
# 96      ['Actor', 'Director', 'Producer']   18 wins , 79 nominations total
# 97        ['Actor', 'Producer', 'Writer']  30 wins , 102 nominations total
# 98  ['Actress', 'Soundtrack', 'Producer']                          28 wins
# 99              ['Actress', 'Soundtrack']    6 wins , 19 nominations total
#
#                 Famous_for                   Birth_place
# 95        The Great Gatsby                 Paris, France
# ...

# %%
df.shape  #Shows rows and columns of dataframe.
# Out:
# (100, 8)

# %%
df.describe() #Shows different statistical values for integer type.
# Out:
#              Rank
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Rank'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...

# %%
df.info()  #Shows datatype and row counts of all columns of dataframe,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           100 non-null    int64
#  1   Name           100 non-null    object
#  2   Date_of_birth  100 non-null    object
#  3   height         96 non-null     object
#  4   Role           100 non-null    object
#  5   Awards         98 non-null     object
#  6   Famous_for     100 non-null    object
#  7   Birth_place    98 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB

# %%
df.iloc[:,2]  #Access a particular column with its Index number.
# Out:
# 0     1995-07-21
# 1     1982-04-05
# 2     1983-10-19
# 3     1988-04-18
# 4     1962-07-03
#          ...
# 95    1990-08-24
# 96    1979-10-20
# 97    1972-09-06
# 98    1997-02-10
# 99    1989-07-21
# Name: Date_of_birth, Length: 100, dtype: object

# %%
df.drop(df.columns[2], axis=1, inplace = True)  #Drops/deletes the mentioned column from the dataframe

# %%
df['Name'].value_counts()   #Shows counts for unique values in a mentioned column.
# Out:
# Anya Chalotra      1
# Ana de Armas       1
# Rachael Taylor     1
# Sophia Lillis      1
# Amanda Peterson    1
#                   ..
# Gabriel Macht      1
# Lauren Lapkus      1
# Molly Gordon       1
# Abbie Cornish      1
# Juno Temple        1
# Name: Name, Length: 100, dtype: int64

# %%
df.Name.unique()  #Shows the unique values given in a dataframe.
# Out:
# array(['Anya Chalotra', 'Hayley Atwell', 'Rebecca Ferguson',
#        'Vanessa Kirby', 'Tom Cruise', 'Freya Allan', 'Pom Klementieff',
#        'Ellen Barkin', 'Florence Pugh', 'Nina Dobrev', 'Cillian Murphy',
#        'Henry Cavill', 'Margot Robbie', 'Jim Caviezel',
#        'Christopher Nolan', 'Ariana Greenblatt', 'Becki Newton',
#        'Timothée Chalamet', 'Lana Parrilla', 'Phoebe Waller-Bridge',
#        'Will Poulter', 'Harrison Ford', 'Isabela Merced',
#        'Jeremy Allen White', 'Kingsley Ben-Adir', 'Mia Kirshner',
#        'Greta Gerwig', 'Abbie Cornish', 'Molly Gordon', 'Lauren Lapkus',
#        'Gabriel Macht', 'Jennifer Lawrence', 'Brad Pitt', 'Liz Katz',
#        'Emily Blunt', 'Poorna Jagannathan', 'Angus Sampson',
#        'Ridley Scott', 'Adam Devine', 'Christina Chong',
#        'Manuel Garcia-Rulfo', 'Jess Bush', 'Rachel Brosnahan',
#        'Karen Gillan', 'Pierce Brosnan', 'Neve Campbell',
#        'Golshifteh Farahani', 'Ryan Gosling', 'Tom Holland',
# ...

# %%
sns.countplot(x ='Rank', data = df, palette = "husl")  #A graphical representation that displays the frequency or count of unique categorical values in dataset
# Out:
# <Axes: xlabel='Rank', ylabel='count'>

# %%
df.to_numpy() #Converts the pandas dataframe to numpy arrays.
# Out:
# array([[1, 'Anya Chalotra', '5′ 6″ (1.68 m)', "['Actress']", '1 win',
#         'The Witcher', 'Wolverhampton, Staffordshire, England, UK'],
#        [2, 'Hayley Atwell', '5′ 6½″ (1.69 m)',
#         "['Actress', 'Soundtrack']", '15 nominations',
#         'Captain America: The First Avenger', 'London, England, UK'],
#        [3, 'Rebecca Ferguson', '5′ 5″ (1.65 m)',
#         "['Actress', 'Soundtrack', 'Producer']", '9 wins',
#         'The Greatest Showman', 'Sweden'],
#        [4, 'Vanessa Kirby', '5′ 7″ (1.70 m)',
#         "['Actress', 'Soundtrack', 'Producer']",
#         '5 wins , 43 nominations total', 'The Crown',
#         'London, England, UK'],
#        [5, 'Tom Cruise', '5′ 7″ (1.70 m)',
#         "['Actor', 'Director', 'Producer']",
#         '59 wins , 108 nominations total', 'Top Gun',
#         'Syracuse, New York, USA'],
#        [6, 'Freya Allan', '5′ 5″ (1.65 m)', "['Actress']",
#         '1 nomination', 'Kingdom of the Planet of the Apes',
# ...

# %%
df['Rank'].map({'M':3,'B':7})  #Changes the values of keys in a particular column to the new integer
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# Name: Rank, Length: 100, dtype: float64

# %%
df.isnull()  #To check if a value in the dataframe is null. (True/False)
# Out:
#      Rank   Name  height   Role  Awards  Famous_for  Birth_place
# 0   False  False   False  False   False       False        False
# 1   False  False   False  False   False       False        False
# 2   False  False   False  False   False       False        False
# 3   False  False   False  False   False       False        False
# 4   False  False   False  False   False       False        False
# ..    ...    ...     ...    ...     ...         ...          ...
# 95  False  False   False  False   False       False        False
# 96  False  False   False  False   False       False        False
# 97  False  False   False  False   False       False        False
# 98  False  False   False  False   False       False        False
# 99  False  False   False  False   False       False        False
#
# [100 rows x 7 columns]

# %%
df.isnull().sum() #To check if a value in the dataframe is null. (True/False)
# Out:
# Rank           0
# Name           0
# height         4
# Role           0
# Awards         2
# Famous_for     0
# Birth_place    2
# dtype: int64

# %%
df.corr()   #Shows sum of all null values in all columns of dataframe.
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#       Rank
# Rank   1.0
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
# ...

# %%
plt.figure(figsize=(4,20))
sns.heatmap(df.corr(), annot=True)
#Shows the dataframe co-relations in form of a heatmap. The lighter the more co-related and vice versa.
# Out:
# <ipython-input-40-f16d6e21778e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
sns.lineplot(x = df['Rank'],y = df['Name'])  )#Shows linear relationship beween 2 columns
# Out:
# <Axes: xlabel='Rank', ylabel='Name'>

# %%
df[['Rank', 'Role']] #Prints specific columns in a dataframe.
# Out:
#     Rank                                   Role
# 0      1                            ['Actress']
# 1      2              ['Actress', 'Soundtrack']
# 2      3  ['Actress', 'Soundtrack', 'Producer']
# 3      4  ['Actress', 'Soundtrack', 'Producer']
# 4      5      ['Actor', 'Director', 'Producer']
# ..   ...                                    ...
# 95    96                ['Actress', 'Producer']
# 96    97      ['Actor', 'Director', 'Producer']
# 97    98        ['Actor', 'Producer', 'Writer']
# 98    99  ['Actress', 'Soundtrack', 'Producer']
# 99   100              ['Actress', 'Soundtrack']
#
# [100 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %%
sns.scatterplot(x = df['Rank'],y = df['Role'])
#A graph that uses individual data points to represent the values of two variables on a 2D plane.
# Out:
# <Axes: xlabel='Rank', ylabel='Role'>

# %%
sns.histplot(df['Birth_place'])
# Out:
# <Axes: xlabel='Birth_place', ylabel='Count'>
